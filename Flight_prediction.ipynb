# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flight = pd.read_excel('./Data_Train.xlsx')
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flight.shape
# Out:
# (10683, 11)

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
flight['Duration'].value_counts()
# Out:
# Duration
# 2h 50m     550
# 1h 30m     386
# 2h 45m     337
# 2h 55m     337
# 2h 35m     329
#           ...
# 31h 30m      1
# 30h 25m      1
# 42h 5m       1
# 4h 10m       1
# 47h 40m      1
# Name: count, Length: 368, dtype: int64

# %%
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
flight.dropna(inplace=True)
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flight['Journey_Day'] = pd.to_datetime(flight.Date_of_Journey , format = '%d/%m/%Y').dt.day
flight['Journey_Month'] = pd.to_datetime(flight.Date_of_Journey , format = '%d/%m/%Y').dt.month
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month
# 0           24              3
# 1            1              5
# 2            9              6
# 3           12              5
# 4            1              3

# %%
flight['Dep_hour'] = pd.to_datetime(flight.Dep_Time ).dt.hour
flight['Dep_Minute'] = pd.to_datetime(flight.Dep_Time ).dt.minute
flight.head()
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\2517023688.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight['Dep_hour'] = pd.to_datetime(flight.Dep_Time ).dt.hour
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\2517023688.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight['Dep_Minute'] = pd.to_datetime(flight.Dep_Time ).dt.minute
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month  Dep_hour  Dep_Minute
# 0           24              3        22          20
# 1            1              5         5          50
# 2            9              6         9          25
# 3           12              5        18           5
# 4            1              3        16          50

# %%
flight['Arrival_hour'] = pd.to_datetime(flight.Arrival_Time ).dt.hour
flight['Arrival_Minute'] = pd.to_datetime(flight.Arrival_Time ).dt.minute
flight.head()
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\4244514515.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight['Arrival_hour'] = pd.to_datetime(flight.Arrival_Time ).dt.hour
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\4244514515.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight['Arrival_Minute'] = pd.to_datetime(flight.Arrival_Time ).dt.minute
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  \
# 0           24              3        22          20             1
# 1            1              5         5          50            13
# 2            9              6         9          25             4
# 3           12              5        18           5            23
# 4            1              3        16          50            21
#
#    Arrival_Minute
# 0              10
# 1              15
# 2              25
# 3              30
# 4              35

# %%
flight.drop(columns=['Dep_Time' , 'Date_of_Journey'],inplace=True)

# %%
flight.drop(columns='Arrival_Time',inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  Dep_hour  \
# 0    non-stop         No info   3897           24              3        22
# 1     2 stops         No info   7662            1              5         5
# 2     2 stops         No info  13882            9              6         9
# 3      1 stop         No info   6218           12              5        18
# 4      1 stop         No info  13302            1              3        16
#
#    Dep_Minute  Arrival_hour  Arrival_Minute
# 0          20             1              10
# 1          50            13              15
# 2          25             4              25
# 3           5            23              30
# 4          50            21              35

# %%
duration = list(flight.Duration)

for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if 'h' in duration[i]:
            duration[i] = duration[i] + ' 0m'
        else:
            duration[i] = '0h ' + duration[i]
            
duration
duration_hour=[]
duration_minute=[]

for i in range(len(duration)):
    duration_hour.append(int(duration[i].split(sep='h')[0] ))
    duration_minute.append(int( duration[i].split('m')[0].split()[-1] ))

# %%
flight['Duration_Hour'] = duration_hour
flight['Duration_Minute'] = duration_minute

# %%
flight.drop(columns='Duration',inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0         No info   3897           24              3        22          20
# 1         No info   7662            1              5         5          50
# 2         No info  13882            9              6         9          25
# 3         No info   6218           12              5        18           5
# 4         No info  13302            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute
# 0             1              10              2               50
# 1            13              15              7               25
# 2             4              25             19                0
# 3            23              30              5               25
# 4            21              35              4               45

# %%
flight['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
sns.catplot(y='Price' , x='Airline' , data = flight.sort_values('Price',ascending=False) , kind='boxen' , height=6 , aspect=3)
# Out:
# C:\Users\akhil\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
Airline = flight['Airline']
Airline = pd.get_dummies(Airline , drop_first=True)
Airline.head()
# Out:
#    Air India  GoAir  IndiGo  Jet Airways  Jet Airways Business  \
# 0      False  False    True        False                 False
# 1       True  False   False        False                 False
# 2      False  False   False         True                 False
# 3      False  False    True        False                 False
# 4      False  False    True        False                 False
#
#    Multiple carriers  Multiple carriers Premium economy  SpiceJet  Trujet  \
# 0              False                              False     False   False
# 1              False                              False     False   False
# 2              False                              False     False   False
# 3              False                              False     False   False
# 4              False                              False     False   False
#
#    Vistara  Vistara Premium economy
# 0    False                    False
# 1    False                    False
# 2    False                    False
# 3    False                    False
# 4    False                    False

# %%
flight['Source'].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
sns.catplot(y='Price' , x='Source' , data = flight.sort_values('Price',ascending=False) , kind='boxen' , height=6 , aspect=3)
# Out:
# C:\Users\akhil\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
flight['Source'].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
Source = flight[['Source']]

Source = pd.get_dummies(Source , drop_first=True)
Source.head()
# Out:
#    Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai
# 0           False         False           False          False
# 1           False         False            True          False
# 2           False          True           False          False
# 3           False         False            True          False
# 4           False         False           False          False

# %%
flight['Destination'].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
Destination = flight[['Destination']]

Destination = pd.get_dummies(Destination , drop_first=True)
Destination.head()
# Out:
#    Destination_Cochin  Destination_Delhi  Destination_Hyderabad  \
# 0               False              False                  False
# 1               False              False                  False
# 2                True              False                  False
# 3               False              False                  False
# 4               False              False                  False
#
#    Destination_Kolkata  Destination_New Delhi
# 0                False                   True
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                   True

# %%
flight['Route']
# Out:
# 0                    BLR → DEL
# 1        CCU → IXR → BBI → BLR
# 2        DEL → LKO → BOM → COK
# 3              CCU → NAG → BLR
# 4              BLR → NAG → DEL
#                  ...
# 10678                CCU → BLR
# 10679                CCU → BLR
# 10680                BLR → DEL
# 10681                BLR → DEL
# 10682    DEL → GOI → BOM → COK
# Name: Route, Length: 10682, dtype: object

# %%
flight.drop(columns=['Route','Additional_Info'],axis=1 , inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source Destination Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi    non-stop   3897           24
# 1    Air India   Kolkata    Banglore     2 stops   7662            1
# 2  Jet Airways     Delhi      Cochin     2 stops  13882            9
# 3       IndiGo   Kolkata    Banglore      1 stop   6218           12
# 4       IndiGo  Banglore   New Delhi      1 stop  13302            1
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  Arrival_Minute  \
# 0              3        22          20             1              10
# 1              5         5          50            13              15
# 2              6         9          25             4              25
# 3              5        18           5            23              30
# 4              3        16          50            21              35
#
#    Duration_Hour  Duration_Minute
# 0              2               50
# 1              7               25
# 2             19                0
# 3              5               25
# 4              4               45

# %%
flight['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
flight.replace( { 'non-stop':0 , '1 stop':1 , '2 stops':2 , '3 stops':3 ,'4 stops':4 } ,inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  Arrival_Minute  \
# 0              3        22          20             1              10
# 1              5         5          50            13              15
# 2              6         9          25             4              25
# 3              5        18           5            23              30
# 4              3        16          50            21              35
#
#    Duration_Hour  Duration_Minute
# 0              2               50
# 1              7               25
# 2             19                0
# 3              5               25
# 4              4               45

# %%
flight = pd.concat( [flight , Airline ,Source , Destination] , axis=1)

# %%
flight.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  ...  \
# 0              3        22          20             1  ...
# 1              5         5          50            13  ...
# 2              6         9          25             4  ...
# 3              5        18           5            23  ...
# 4              3        16          50            21  ...
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True
#
# [5 rows x 33 columns]

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
flight.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  Arrival_Minute  \
# 0              3        22          20             1              10
# 1              5         5          50            13              15
# 2              6         9          25             4              25
# 3              5        18           5            23              30
# 4              3        16          50            21              35
#
#    Duration_Hour  Duration_Minute  Air India  GoAir  IndiGo  Jet Airways  \
# 0              2               50      False  False    True        False
# 1              7               25       True  False   False        False
# 2             19                0      False  False   False         True
# 3              5               25      False  False    True        False
# 4              4               45      False  False    True        False
#
#    Jet Airways Business  Multiple carriers  Multiple carriers Premium economy  \
# 0                 False              False                              False
# 1                 False              False                              False
# 2                 False              False                              False
# 3                 False              False                              False
# 4                 False              False                              False
#
#    SpiceJet  Trujet  Vistara  Vistara Premium economy  Source_Chennai  \
# 0     False   False    False                    False           False
# 1     False   False    False                    False           False
# 2     False   False    False                    False           False
# 3     False   False    False                    False           False
# 4     False   False    False                    False           False
#
#    Source_Delhi  Source_Kolkata  Source_Mumbai  Destination_Cochin  \
# 0         False           False          False               False
# 1         False            True          False               False
# 2          True           False          False                True
# 3         False            True          False               False
# 4         False           False          False               False
#
#    Destination_Delhi  Destination_Hyderabad  Destination_Kolkata  \
# 0              False                  False                False
# 1              False                  False                False
# 2              False                  False                False
# 3              False                  False                False
# 4              False                  False                False
#
#    Destination_New Delhi
# 0                   True
# 1                  False
# 2                  False
# 3                  False
# 4                   True

# %%
flight.drop(columns = [ 'Airline' , 'Source' , 'Destination' ] , inplace=True)

# %%
flight.head()
# Out:
#    Total_Stops  Price  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            0   3897           24              3        22          20
# 1            2   7662            1              5         5          50
# 2            2  13882            9              6         9          25
# 3            1   6218           12              5        18           5
# 4            1  13302            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             1              10              2               50      False
# 1            13              15              7               25       True
# 2             4              25             19                0      False
# 3            23              30              5               25      False
# 4            21              35              4               45      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False    True        False                 False              False
# 1  False   False        False                 False              False
# 2  False   False         True                 False              False
# 3  False    True        False                 False              False
# 4  False    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
# 2                              False     False   False    False
# 3                              False     False   False    False
# 4                              False     False   False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True

# %%
flight.shape
# Out:
# (10682, 30)

# %% [markdown]
# ## Test Data

# %%
flight_test = pd.read_excel('./Data_Test.xlsx')
flight_test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
print("-"*50)
print("Shape")
print(flight_test.shape)

print("-"*50)
print("Info")
print(flight_test.info())

print("-"*50)
print("Duration count values")
print(flight_test['Duration'].value_counts())

print("-"*50)
print("Check null value")
print(flight_test.isnull().sum())

print("-"*50)
print("Drop null value rows")
flight_test.dropna(inplace=True)

print("-"*50)
print("Check null values")
print(flight_test.isnull().sum())

print("-"*50)
print("Fetch journey day and month from Date_of_Journey")
flight_test['Journey_Day'] = pd.to_datetime(flight_test.Date_of_Journey , format = '%d/%m/%Y').dt.day
flight_test['Journey_Month'] = pd.to_datetime(flight_test.Date_of_Journey , format = '%d/%m/%Y').dt.month
print(flight_test.head())

print("-"*50)
print("Fetch Departure hours and minutes from Dep_Time")
flight_test['Dep_hour'] = pd.to_datetime(flight_test.Dep_Time ).dt.hour
flight_test['Dep_Minute'] = pd.to_datetime(flight_test.Dep_Time ).dt.minute
print(flight_test.head())

print("-"*50)
print("Drop Dep_time and Date_of_Journey columns")
flight_test.drop(columns=['Dep_Time' , 'Date_of_Journey'],inplace=True)

print("-"*50)
print("Fetch journey hours and minutes from Arrival_Time")
flight_test['Arrival_hour'] = pd.to_datetime(flight_test.Arrival_Time ).dt.hour
flight_test['Arrival_Minute'] = pd.to_datetime(flight_test.Arrival_Time ).dt.minute
print(flight_test.head())

print("-"*50)
print("Drop Arrival_Time columns")
flight_test.drop(columns='Arrival_Time',inplace=True)

print("-"*50)
print("Fetch  hours and minutes from Durations")
duration = list(flight_test.Duration)

for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if 'h' in duration[i]:
            duration[i] = duration[i] + ' 0m'
        else:
            duration[i] = '0h ' + duration[i]
            
duration
duration_hour=[]
duration_minute=[]

for i in range(len(duration)):
    duration_hour.append(int(duration[i].split(sep='h')[0] ))
    duration_minute.append(int( duration[i].split('m')[0].split()[-1] ))

flight_test['Duration_Hour'] = duration_hour
flight_test['Duration_Minute'] = duration_minute
flight_test.drop(columns='Duration',inplace=True)

print("-"*50)
print("Count Airline values")
print(flight_test['Airline'].value_counts())


print("-"*50)
print("OneHotEncoder on Airline Column")
Airline = flight_test['Airline']
Airline = pd.get_dummies(Airline , drop_first=True)
print(Airline.head())

print("-"*50)
print("Count Source values")
print(flight_test['Source'].value_counts())


print("-"*50)
print("Count Source values")
print(flight_test['Source'].value_counts())

print("-"*50)
print("OneHotEncoder on Source Column")
Source = flight_test[['Source']]
Source = pd.get_dummies(Source , drop_first=True)
print(Source.head())

print("-"*50)
print("Count Destination values")
print(flight_test['Destination'].value_counts())

print("-"*50)
print("OneHotEncoder on Destination Column")
Destination = flight_test[['Destination']]
Destination = pd.get_dummies(Destination , drop_first=True)
print(Destination.head())

print("-"*50)
print("Show route")
print(flight_test['Route'])

print("-"*50)
print("Drop Route and Additional_Info")
flight_test.drop(columns=['Route','Additional_Info'],axis=1 , inplace=True)

print("-"*50)
print("Cout Total_Stops")
print(flight_test['Total_Stops'].value_counts())

print("-"*50)
print("Normalize total stops")
flight_test.replace( { 'non-stop':0 , '1 stop':1 , '2 stops':2 , '3 stops':3 ,'4 stops':4 } ,inplace=True)

print("-"*50)
print("Concate flight, airline, source and destionation")
flight_test = pd.concat( [flight_test , Airline ,Source , Destination] , axis=1)

print("-"*50)
print("Show all rows and columns")
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

print("-"*50)
print("Drop Airline, Source and Destination")
flight_test.drop(columns = [ 'Airline' , 'Source' , 'Destination' ] , inplace=True)

print("-"*50)
print("Show head")
print(flight_test.head())

print("-"*50)
print("Shape")
print(flight_test.shape)
# Out:
# --------------------------------------------------
# Shape
# (2671, 10)
# --------------------------------------------------
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB
# None
# --------------------------------------------------
# Duration count values
# Duration
# 2h 50m     122
# 1h 30m     107
# 2h 45m      95
# 2h 55m      81
# 3h          72
# 2h 35m      70
# 2h 30m      58
# 2h 20m      48
# 2h 40m      38
# 13h 20m     32
# 5h 15m      29
# 2h 15m      29
# 2h 25m      24
# 1h 25m      24
# 10h 15m     22
# 13h 30m     22
# 9h 20m      22
# 1h 20m      20
# 3h 15m      20
# 14h 5m      20
# 7h 30m      19
# 12h 30m     18
# 11h         18
# 13h         18
# 7h 35m      18
# 10h 25m     17
# 9h 30m      17
# 6h 25m      17
# 3h 5m       17
# 11h 45m     17
# 12h 10m     16
# 8h          16
# 5h 30m      16
# 5h 45m      16
# 8h 40m      16
# 8h 25m      16
# 12h 45m     15
# 22h 55m     15
# 7h 15m      15
# 10h         15
# 23h 40m     14
# 8h 30m      14
# 11h 30m     14
# 6h 20m      14
# 6h 35m      14
# 9h          14
# 15h 10m     13
# 4h 50m      13
# 5h          13
# 9h 50m      12
# 6h 15m      12
# 12h 15m     12
# 18h 20m     12
# 18h 45m     12
# 12h 25m     12
# 14h         12
# 11h 15m     12
# 7h 5m       12
# 27h 35m     12
# 10h 30m     12
# 19h 25m     12
# 5h 20m      12
# 26h 20m     11
# 23h 50m     11
# 14h 30m     11
# 22h 30m     11
# 3h 10m      11
# 25h 45m     11
# 7h 20m      11
# 7h 45m      11
# 9h 45m      11
# 8h 20m      10
# 26h 55m     10
# 14h 20m     10
# 16h 5m      10
# 12h         10
# 26h 35m      9
# 6h 30m       9
# 15h 40m      9
# 11h 25m      9
# 7h 55m       9
# 12h 20m      9
# 13h 15m      9
# 11h 5m       9
# 6h 5m        9
# 15h 25m      9
# 9h 15m       9
# 6h 40m       9
# 20h 55m      8
# 19h 55m      8
# 23h 30m      8
# 5h 10m       8
# 14h 55m      8
# 16h 45m      8
# 16h 50m      8
# 21h 15m      8
# 21h 35m      8
# 17h 5m       8
# 22h 5m       8
# 10h 10m      8
# 21h 55m      8
# 13h 45m      8
# 4h 35m       7
# 7h 40m       7
# 1h 35m       7
# 15h 55m      7
# 20h          7
# 8h 55m       7
# 24h 50m      7
# 8h 10m       7
# 4h 55m       7
# 27h 45m      7
# 14h 35m      7
# 17h 25m      7
# 8h 50m       7
# 9h 35m       7
# 13h 50m      7
# 5h 55m       7
# 6h           6
# 4h 5m        6
# 22h 25m      6
# 24h 45m      6
# 21h 25m      6
# 10h 50m      6
# 25h 40m      6
# 16h 15m      6
# 11h 50m      6
# 23h 45m      6
# 7h 50m       6
# 6h 10m       6
# 1h 15m       6
# 33h 15m      6
# 4h 30m       6
# 5h 25m       6
# 15h 15m      6
# 5h 40m       6
# 15h 30m      6
# 23h 15m      6
# 27h 40m      6
# 20h 20m      6
# 5h 5m        6
# 11h 40m      6
# 14h 25m      6
# 10h 20m      6
# 20h 10m      6
# 26h          6
# 28h          5
# 5h 35m       5
# 12h 35m      5
# 37h 20m      5
# 4h 40m       5
# 27h 10m      5
# 10h 40m      5
# 17h 35m      5
# 16h 25m      5
# 14h 50m      5
# 9h 10m       5
# 22h 45m      5
# 3h 40m       5
# 13h 55m      5
# 20h 15m      5
# 23h 10m      5
# 24h 30m      5
# 10h 35m      5
# 15h 5m       5
# 24h          5
# 24h 40m      5
# 8h 5m        4
# 15h          4
# 15h 20m      4
# 15h 45m      4
# 4h 25m       4
# 36h 25m      4
# 27h 5m       4
# 24h 10m      4
# 25h          4
# 20h 45m      4
# 12h 55m      4
# 25h 35m      4
# 10h 55m      4
# 26h 25m      4
# 23h 35m      4
# 9h 5m        4
# 12h 50m      4
# 23h          4
# 13h 25m      4
# 16h          4
# 21h 10m      4
# 8h 15m       4
# 25h 50m      4
# 19h 40m      4
# 18h 25m      4
# 25h 20m      4
# 24h 55m      4
# 25h 30m      4
# 11h 35m      4
# 14h 45m      4
# 28h 40m      4
# 11h 55m      3
# 5h 50m       3
# 22h 10m      3
# 30h 30m      3
# 29h 5m       3
# 17h 55m      3
# 29h 35m      3
# 30h 20m      3
# 7h           3
# 27h          3
# 8h 35m       3
# 29h 20m      3
# 28h 15m      3
# 8h 45m       3
# 28h 20m      3
# 22h 15m      3
# 20h 35m      3
# 18h          3
# 27h 20m      3
# 4h 45m       3
# 19h 30m      3
# 17h 15m      3
# 23h 5m       3
# 12h 40m      3
# 4h           3
# 38h 15m      3
# 21h 40m      3
# 35h 35m      3
# 28h 50m      3
# 23h 20m      3
# 12h 5m       2
# 30h          2
# 22h          2
# 24h 25m      2
# 25h 10m      2
# 16h 40m      2
# 9h 40m       2
# 26h 5m       2
# 24h 5m       2
# 18h 30m      2
# 26h 15m      2
# 30h 40m      2
# 6h 55m       2
# 15h 50m      2
# 25h 5m       2
# 25h 55m      2
# 14h 10m      2
# 9h 25m       2
# 21h 45m      2
# 17h 20m      2
# 16h 55m      2
# 16h 20m      2
# 10h 45m      2
# 11h 10m      2
# 26h 30m      2
# 16h 35m      2
# 26h 10m      2
# 19h 10m      2
# 15h 35m      2
# 17h 45m      2
# 23h 55m      2
# 38h          2
# 25h 25m      2
# 16h 10m      2
# 19h          2
# 28h 10m      2
# 6h 50m       2
# 6h 45m       2
# 18h 10m      2
# 26h 40m      2
# 18h 50m      2
# 14h 40m      2
# 13h 10m      2
# 11h 20m      2
# 10h 5m       2
# 9h 55m       1
# 17h 40m      1
# 38h 20m      1
# 19h 5m       1
# 24h 35m      1
# 4h 20m       1
# 7h 25m       1
# 16h 30m      1
# 17h 30m      1
# 22h 50m      1
# 27h 55m      1
# 27h 30m      1
# 40h 40m      1
# 24h 20m      1
# 38h 35m      1
# 28h 5m       1
# 30h 25m      1
# 32h 25m      1
# 33h 45m      1
# 19h 45m      1
# 22h 40m      1
# 24h 15m      1
# 4h 10m       1
# 20h 30m      1
# 31h 55m      1
# 34h 30m      1
# 26h 50m      1
# 33h 20m      1
# 13h 35m      1
# 21h 5m       1
# 13h 5m       1
# 29h 40m      1
# 21h 20m      1
# 3h 45m       1
# 31h 10m      1
# 20h 25m      1
# 7h 10m       1
# 18h 40m      1
# 27h 50m      1
# 39h 5m       1
# 19h 15m      1
# 29h 55m      1
# 30h 45m      1
# 32h 5m       1
# 32h 20m      1
# 28h 55m      1
# 5m           1
# Name: count, dtype: int64
# --------------------------------------------------
# Check null value
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64
# --------------------------------------------------
# Drop null value rows
# --------------------------------------------------
# Check null values
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64
# --------------------------------------------------
# Fetch journey day and month from Date_of_Journey
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Journey_Day  Journey_Month
# 0            6              6
# 1           12              5
# 2           21              5
# 3           21              5
# 4           24              6
# --------------------------------------------------
# Fetch Departure hours and minutes from Dep_Time
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Journey_Day  Journey_Month  Dep_hour  Dep_Minute
# 0            6              6        17          30
# 1           12              5         6          20
# 2           21              5        19          15
# 3           21              5         8           0
# 4           24              6        23          55
# --------------------------------------------------
# Drop Dep_time and Date_of_Journey columns
# --------------------------------------------------
# Fetch journey hours and minutes from Arrival_Time
#              Airline    Source Destination            Route  Arrival_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  04:25 07 Jun
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR         10:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  19:00 22 May
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK         21:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL  02:45 25 Jun
#
#   Duration Total_Stops              Additional_Info  Journey_Day  \
# 0  10h 55m      1 stop                      No info            6
# 1       4h      1 stop                      No info           12
# 2  23h 45m      1 stop  In-flight meal not included           21
# 3      13h      1 stop                      No info           21
# 4   2h 50m    non-stop                      No info           24
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  Arrival_Minute
# 0              6        17          30             4              25
# 1              5         6          20            10              20
# 2              5        19          15            19               0
# 3              5         8           0            21               0
# 4              6        23          55             2              45
# --------------------------------------------------
# Drop Arrival_Time columns
# --------------------------------------------------
# Fetch  hours and minutes from Durations
# --------------------------------------------------
# Count Airline values
# Airline
# Jet Airways                          897
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Jet Airways Business                   2
# Name: count, dtype: int64
# --------------------------------------------------
# OneHotEncoder on Airline Column
#    Air India  GoAir  IndiGo  Jet Airways  Jet Airways Business  \
# 0      False  False   False         True                 False
# 1      False  False    True        False                 False
# 2      False  False   False         True                 False
# 3      False  False   False        False                 False
# 4      False  False   False        False                 False
#
#    Multiple carriers  Multiple carriers Premium economy  SpiceJet  Vistara  \
# 0              False                              False     False    False
# 1              False                              False     False    False
# 2              False                              False     False    False
# 3               True                              False     False    False
# 4              False                              False     False    False
#
#    Vistara Premium economy
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# --------------------------------------------------
# Count Source values
# Source
# Delhi       1145
# Kolkata      710
# Banglore     555
# Mumbai       186
# Chennai       75
# Name: count, dtype: int64
# --------------------------------------------------
# Count Source values
# Source
# Delhi       1145
# Kolkata      710
# Banglore     555
# Mumbai       186
# Chennai       75
# Name: count, dtype: int64
# --------------------------------------------------
# OneHotEncoder on Source Column
#    Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai
# 0           False          True           False          False
# 1           False         False            True          False
# 2           False          True           False          False
# 3           False          True           False          False
# 4           False         False           False          False
# --------------------------------------------------
# Count Destination values
# Destination
# Cochin       1145
# Banglore      710
# Delhi         317
# New Delhi     238
# Hyderabad     186
# Kolkata        75
# Name: count, dtype: int64
# --------------------------------------------------
# OneHotEncoder on Destination Column
#    Destination_Cochin  Destination_Delhi  Destination_Hyderabad  \
# 0                True              False                  False
# 1               False              False                  False
# 2                True              False                  False
# 3                True              False                  False
# 4               False               True                  False
#
#    Destination_Kolkata  Destination_New Delhi
# 0                False                  False
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                  False
# --------------------------------------------------
# Show route
# 0                         DEL → BOM → COK
# 1                         CCU → MAA → BLR
# 2                         DEL → BOM → COK
# 3                         DEL → BOM → COK
# 4                               BLR → DEL
# 5                         DEL → BOM → COK
# 6                         BLR → TRV → DEL
# 7                         CCU → HYD → BLR
# 8                               CCU → BLR
# 9                         CCU → BOM → BLR
# 10                  DEL → MAA → BOM → COK
# 11                        DEL → HYD → COK
# 12                        DEL → BOM → COK
# 13                        BLR → BOM → DEL
# 14                        DEL → BOM → COK
# 15                        BLR → BOM → DEL
# 16                        DEL → HYD → COK
# 17                        CCU → DEL → BLR
# 18                        DEL → BOM → COK
# 19                        BLR → BOM → DEL
# 20                        DEL → BOM → COK
# 21                        CCU → BOM → BLR
# 22                        BLR → BOM → DEL
# 23                  DEL → JAI → BOM → COK
# 24                              BLR → DEL
# 25                        DEL → BOM → COK
# 26                              CCU → BLR
# 27                        DEL → BOM → COK
# 28                        DEL → BOM → COK
# 29                        DEL → BOM → COK
# 30                              CCU → BLR
# 31                        DEL → BOM → COK
# 32                  DEL → BHO → BOM → COK
# 33                              BLR → DEL
# 34                              BOM → HYD
# 35                              BLR → DEL
# 36                              BOM → HYD
# 37                        BLR → BOM → DEL
# 38                        CCU → BOM → BLR
# 39                        DEL → BOM → COK
# 40                              CCU → BLR
# 41                        DEL → BOM → COK
# 42                              BOM → HYD
# 43                        DEL → BOM → COK
# 44                        CCU → PNQ → BLR
# 45                              MAA → CCU
# 46                        DEL → BOM → COK
# 47                              BOM → HYD
# 48                        CCU → BOM → BLR
# 49                        DEL → BOM → COK
# 50                  CCU → BOM → COK → BLR
# 51                        CCU → BOM → BLR
# 52                        CCU → BOM → BLR
# 53                        BLR → BOM → DEL
# 54                              MAA → CCU
# 55                              BLR → DEL
# 56                        DEL → BLR → COK
# 57                        BLR → BOM → DEL
# 58                        DEL → HYD → COK
# 59                        CCU → DEL → BLR
# 60                        DEL → BOM → COK
# 61                  DEL → HYD → MAA → COK
# 62                        DEL → BLR → COK
# 63                        DEL → BLR → COK
# 64                              BLR → DEL
# 65                              BLR → DEL
# 66                        DEL → MAA → COK
# 67                        DEL → BOM → COK
# 68                              BLR → DEL
# 69                        DEL → BOM → COK
# 70                              BOM → HYD
# 71                        DEL → BOM → COK
# 72            CCU → IXR → BBI → BOM → BLR
# 73                        DEL → BLR → COK
# 74                              BOM → HYD
# 75                              BLR → DEL
# 76                              BLR → DEL
# 77                  CCU → DEL → AMD → BLR
# 78                              DEL → COK
# 79                        CCU → BOM → BLR
# 80                              BLR → DEL
# 81                        CCU → DEL → BLR
# 82                        DEL → BOM → COK
# 83                              CCU → BLR
# 84                        DEL → BOM → COK
# 85                        DEL → BOM → COK
# 86                              MAA → CCU
# 87                        DEL → BOM → COK
# 88                              CCU → BLR
# 89                        CCU → BOM → BLR
# 90                        CCU → BOM → BLR
# 91                        CCU → BOM → BLR
# 92                        DEL → BOM → COK
# 93                        DEL → BOM → COK
# 94                              BOM → HYD
# 95                              BOM → HYD
# 96                        DEL → BOM → COK
# 97                        DEL → BOM → COK
# 98                              BOM → HYD
# 99                  CCU → JAI → BOM → BLR
# 100                       DEL → LKO → COK
# 101                       DEL → BOM → COK
# 102                       DEL → BOM → COK
# 103                       DEL → BOM → COK
# 104                             CCU → BLR
# 105                       CCU → BOM → BLR
# 106                             BOM → HYD
# 107                       BLR → BOM → DEL
# 108                 DEL → HYD → MAA → COK
# 109                       DEL → BOM → COK
# 110                       DEL → BOM → COK
# 111                       DEL → BOM → COK
# 112                             CCU → BLR
# 113                       CCU → MAA → BLR
# 114                       CCU → IXB → BLR
# 115                 DEL → CCU → BOM → COK
# 116                       BLR → BOM → DEL
# 117                       DEL → BOM → COK
# 118                 DEL → BHO → BOM → COK
# 119                       DEL → BOM → COK
# 120                 CCU → GAU → DEL → BLR
# 121                       BLR → BOM → DEL
# 122                             CCU → BLR
# 123                             BLR → DEL
# 124                       CCU → MAA → BLR
# 125                       DEL → BOM → COK
# 126                             CCU → BLR
# 127                             BLR → DEL
# 128                       DEL → HYD → COK
# 129                             BLR → DEL
# 130                       DEL → BOM → COK
# 131                       DEL → HYD → COK
# 132                       DEL → LKO → COK
# 133                             CCU → BLR
# 134                             BLR → DEL
# 135                       CCU → BOM → BLR
# 136                 CCU → DEL → AMD → BLR
# 137                             BLR → DEL
# 138                             BLR → DEL
# 139                       BLR → COK → DEL
# 140                             BLR → DEL
# 141                       CCU → BOM → BLR
# 142                       DEL → BOM → COK
# 143                       CCU → BOM → BLR
# 144                             BLR → DEL
# 145                       DEL → MAA → COK
# 146                             BLR → DEL
# 147                             CCU → BLR
# 148                       CCU → BOM → BLR
# 149                       DEL → BLR → COK
# 150                       CCU → BOM → BLR
# 151                       DEL → HYD → COK
# 152                       DEL → BOM → COK
# 153                             BLR → DEL
# 154                             CCU → BLR
# 155                             BLR → DEL
# 156                             CCU → BLR
# 157                             BLR → DEL
# 158                       CCU → BOM → BLR
# 159                             BOM → HYD
# 160                             BLR → DEL
# 161                       DEL → BOM → COK
# 162                             BLR → DEL
# 163                             CCU → BLR
# 164                             BLR → DEL
# 165                             BLR → DEL
# 166                 DEL → HYD → MAA → COK
# 167                             CCU → BLR
# 168                       CCU → PNQ → BLR
# 169                             MAA → CCU
# 170                 DEL → CCU → BOM → COK
# 171                 DEL → JAI → BOM → COK
# 172                             BLR → DEL
# 173                             BLR → DEL
# 174                 BLR → BOM → NAG → DEL
# 175                             CCU → BLR
# 176                       CCU → MAA → BLR
# 177                 CCU → BBI → BOM → BLR
# 178                       DEL → BOM → COK
# 179                       CCU → BOM → BLR
# 180                       CCU → BOM → BLR
# 181                             BOM → HYD
# 182                             CCU → BLR
# 183                       BLR → BOM → DEL
# 184                       DEL → BOM → COK
# 185                       BLR → AMD → DEL
# 186                       CCU → DEL → BLR
# 187                       DEL → BOM → COK
# 188                       DEL → BLR → COK
# 189                             CCU → BLR
# 190                       DEL → BOM → COK
# 191                       BOM → DEL → HYD
# 192                             BOM → HYD
# 193                       DEL → BOM → COK
# 194                 DEL → GOI → BOM → COK
# 195                             MAA → CCU
# 196                 CCU → JAI → BOM → BLR
# 197                       DEL → BLR → COK
# 198                             BLR → DEL
# 199                       CCU → BOM → BLR
# 200                       DEL → BOM → COK
# 201                       DEL → BOM → COK
# 202                       CCU → BOM → BLR
# 203                             MAA → CCU
# 204                       DEL → HYD → COK
# 205                             BLR → DEL
# 206                       DEL → BOM → COK
# 207                 DEL → JAI → BOM → COK
# 208                 DEL → HYD → MAA → COK
# 209                       CCU → DEL → BLR
# 210                             DEL → COK
# 211                 CCU → BBI → BOM → BLR
# 212                       CCU → DEL → BLR
# 213                       DEL → HYD → COK
# 214                 DEL → IXU → BOM → COK
# 215                       CCU → BOM → BLR
# 216                       CCU → BOM → BLR
# 217                 DEL → HYD → BOM → COK
# 218                 DEL → JAI → BOM → COK
# 219                       BOM → DEL → HYD
# 220                             BLR → DEL
# 221                       DEL → BOM → COK
# 222                       DEL → BOM → COK
# 223                             MAA → CCU
# 224                             CCU → BLR
# 225                 DEL → JAI → BOM → COK
# 226                             CCU → BLR
# 227                             BOM → HYD
# 228                       DEL → MAA → COK
# 229                       CCU → DEL → BLR
# 230                 CCU → DEL → COK → BLR
# 231                       CCU → BOM → BLR
# 232                             BOM → HYD
# 233                       BLR → BOM → DEL
# 234                             BLR → DEL
# 235                       BLR → GOI → DEL
# 236                 DEL → IXU → BOM → COK
# 237                             CCU → BLR
# 238                       DEL → BOM → COK
# 239                       CCU → HYD → BLR
# 240                       CCU → DEL → BLR
# 241                       DEL → BOM → COK
# 242                 BLR → BOM → BHO → DEL
# 243                             BLR → DEL
# 244                 DEL → IDR → BOM → COK
# 245                 DEL → AMD → BOM → COK
# 246                 CCU → JAI → BOM → BLR
# 247                             BLR → DEL
# 248                       DEL → BOM → COK
# 249                       DEL → BOM → COK
# 250                 DEL → IDR → BOM → COK
# 251           DEL → RPR → NAG → BOM → COK
# 252                       DEL → BOM → COK
# 253                       DEL → BOM → COK
# 254                       DEL → BOM → COK
# 255                 DEL → NAG → BOM → COK
# 256                       DEL → HYD → COK
# 257                             DEL → COK
# 258                 DEL → AMD → BOM → COK
# 259                       CCU → PAT → BLR
# 260                 CCU → GAU → DEL → BLR
# 261                             BOM → HYD
# 262                             BLR → DEL
# 263                       CCU → BOM → BLR
# 264                             BLR → DEL
# 265                             BLR → DEL
# 266                 DEL → AMD → BOM → COK
# 267                             BLR → DEL
# 268                       CCU → BOM → BLR
# 269                       DEL → BOM → COK
# 270                       DEL → BOM → COK
# 271                 CCU → DEL → AMD → BLR
# 272                             BLR → DEL
# 273                       DEL → BLR → COK
# 274                       CCU → DEL → BLR
# 275                             BLR → DEL
# 276                       DEL → HYD → COK
# 277                       CCU → BOM → BLR
# 278                       CCU → BOM → BLR
# 279                             BLR → DEL
# 280                       DEL → HYD → COK
# 281                       DEL → BOM → COK
# 282                       DEL → MAA → COK
# 283                       CCU → DEL → BLR
# 284                 BLR → HYD → VGA → DEL
# 285                             CCU → BLR
# 286                             BLR → DEL
# 287                       DEL → BLR → COK
# 288                       DEL → BOM → COK
# 289                       DEL → HYD → COK
# 290                       DEL → BOM → COK
# 291                 BLR → BOM → IXC → DEL
# 292                 DEL → HYD → MAA → COK
# 293                       CCU → DEL → BLR
# 294                 DEL → JAI → BOM → COK
# 295                       BOM → DEL → HYD
# 296                       CCU → DEL → BLR
# 297                 CCU → GAU → DEL → BLR
# 298                       CCU → BOM → BLR
# 299                 BLR → BOM → IDR → DEL
# 300                       CCU → HYD → BLR
# 301                             BLR → DEL
# 302                             MAA → CCU
# 303                       DEL → BOM → COK
# 304                       BLR → BOM → DEL
# 305                       DEL → BOM → COK
# 306                       CCU → DEL → BLR
# 307                             BOM → HYD
# 308                       DEL → BOM → COK
# 309                       CCU → HYD → BLR
# 310                             BLR → DEL
# 311                       CCU → DEL → BLR
# 312                 CCU → VNS → DEL → BLR
# 313                       CCU → BOM → BLR
# 314                             BOM → HYD
# 315                 DEL → JAI → BOM → COK
# 316                       DEL → MAA → COK
# 317                       CCU → BOM → BLR
# 318                       DEL → BOM → COK
# 319                       CCU → BBI → BLR
# 320                       BLR → MAA → DEL
# 321                             BLR → DEL
# 322                       BLR → BOM → DEL
# 323                       DEL → BOM → COK
# 324                 BLR → BOM → BHO → DEL
# 325                             MAA → CCU
# 326                       DEL → BOM → COK
# 327                       CCU → DEL → BLR
# 328                       DEL → BLR → COK
# 329                 DEL → HYD → BOM → COK
# 330                             BLR → DEL
# 331                             BLR → DEL
# 332                             BOM → HYD
# 333                             BLR → DEL
# 334                       DEL → BOM → COK
# 335                             BLR → DEL
# 336                       DEL → BOM → COK
# 337                       CCU → BOM → BLR
# 338                 CCU → IXR → DEL → BLR
# 339                 DEL → HYD → BOM → COK
# 340                             BLR → DEL
# 341                 CCU → BOM → GOI → BLR
# 342                       DEL → BOM → COK
# 343                             BOM → HYD
# 344                 CCU → BOM → COK → BLR
# 345                             CCU → BLR
# 346                       CCU → BOM → BLR
# 347                       CCU → HYD → BLR
# 348                       CCU → BOM → BLR
# 349                 DEL → ATQ → BOM → COK
# 350                 DEL → IDR → BOM → COK
# 351                       CCU → DEL → BLR
# 352                       DEL → BOM → COK
# 353                       DEL → BOM → COK
# 354                       CCU → BOM → BLR
# 355                       DEL → HYD → COK
# 356                       BLR → BOM → DEL
# 357                       BLR → BOM → DEL
# 358                       DEL → BLR → COK
# 359                       DEL → BOM → COK
# 360                             CCU → BLR
# 361                       DEL → HYD → COK
# 362                             BOM → HYD
# 363                       CCU → DEL → BLR
# 364                       CCU → DEL → BLR
# 365                       DEL → BOM → COK
# 366                             BOM → HYD
# 367                       BLR → VGA → DEL
# 368                             BLR → DEL
# 369                       BLR → BOM → DEL
# 370                             BLR → DEL
# 371                       DEL → BOM → COK
# 372                             BLR → DEL
# 373                             CCU → BLR
# 374                       BLR → BOM → DEL
# 375                       CCU → DEL → BLR
# 376                       DEL → BOM → COK
# 377                       CCU → BOM → BLR
# 378                       DEL → MAA → COK
# 379                       CCU → PNQ → BLR
# 380                       DEL → BOM → COK
# 381                       CCU → BOM → BLR
# 382                       DEL → BOM → COK
# 383                             BLR → DEL
# 384                       DEL → BOM → COK
# 385                       DEL → BOM → COK
# 386                             BOM → HYD
# 387                             CCU → BLR
# 388                             CCU → BLR
# 389                       BLR → BOM → DEL
# 390                 DEL → AMD → BOM → COK
# 391                       DEL → BOM → COK
# 392                             BLR → DEL
# 393                             BLR → DEL
# 394                       DEL → BOM → COK
# 395                       DEL → HYD → COK
# 396                       CCU → BOM → BLR
# 397                             BLR → DEL
# 398                       BLR → BOM → DEL
# 399                             BLR → DEL
# 400                       CCU → BOM → BLR
# 401                             BLR → DEL
# 402                       CCU → DEL → BLR
# 403                             CCU → BLR
# 404                       DEL → BOM → COK
# 405                 DEL → JAI → BOM → COK
# 406                             CCU → BLR
# 407                       DEL → BOM → COK
# 408                       DEL → BOM → COK
# 409                       CCU → BOM → BLR
# 410                       DEL → BOM → COK
# 411                             CCU → BLR
# 412                       CCU → DEL → BLR
# 413                 DEL → BDQ → BOM → COK
# 414                 DEL → IDR → BOM → COK
# 415                             BLR → DEL
# 416                 DEL → CCU → BOM → COK
# 417                 DEL → JAI → BOM → COK
# 418                       BLR → BOM → DEL
# 419                       BLR → HYD → DEL
# 420                       DEL → BOM → COK
# 421                       CCU → HYD → BLR
# 422                       DEL → HYD → COK
# 423                 BLR → BOM → AMD → DEL
# 424                       DEL → BOM → COK
# 425                             BOM → HYD
# 426                             BLR → DEL
# 427                             CCU → BLR
# 428                       DEL → BOM → COK
# 429                       CCU → BOM → BLR
# 430                       BLR → BOM → DEL
# 431                       DEL → BOM → COK
# 432                             BOM → HYD
# 433                             MAA → CCU
# 434                             CCU → BLR
# 435                       CCU → BOM → BLR
# 436                       CCU → MAA → BLR
# 437                       DEL → BOM → COK
# 438                       DEL → BOM → COK
# 439                       DEL → BOM → COK
# 440                       DEL → BOM → COK
# 441                             BOM → HYD
# 442                       CCU → DEL → BLR
# 443                             MAA → CCU
# 444                       DEL → BOM → COK
# 445                       DEL → BOM → COK
# 446                 DEL → JAI → BOM → COK
# 447                             CCU → BLR
# 448                       DEL → BOM → COK
# 449                       DEL → HYD → COK
# 450                       DEL → HYD → COK
# 451                       CCU → BOM → BLR
# 452                       CCU → DEL → BLR
# 453                       CCU → DEL → BLR
# 454                       DEL → BOM → COK
# 455                       DEL → HYD → COK
# 456                             BLR → DEL
# 457                       CCU → BOM → BLR
# 458                       DEL → BOM → COK
# 459                       CCU → BOM → BLR
# 460                 DEL → DED → BOM → COK
# 461                 CCU → DEL → COK → BLR
# 462                       CCU → BOM → BLR
# 463                 CCU → BOM → GOI → BLR
# 464                             DEL → COK
# 465                 DEL → JAI → BOM → COK
# 466                       DEL → MAA → COK
# 467                             DEL → COK
# 468                             CCU → BLR
# 469                       BLR → COK → DEL
# 470                       CCU → DEL → BLR
# 471                       CCU → BOM → BLR
# 472                             MAA → CCU
# 473                       DEL → BOM → COK
# 474                       DEL → BOM → COK
# 475                       DEL → BOM → COK
# 476                             CCU → BLR
# 477                             CCU → BLR
# 478                       CCU → BOM → BLR
# 479                       CCU → DEL → BLR
# 480                       DEL → BOM → COK
# 481                       DEL → BOM → COK
# 482                       DEL → BOM → COK
# 483                       DEL → AMD → COK
# 484           CCU → IXR → BBI → BOM → BLR
# 485                 DEL → IXU → BOM → COK
# 486                       CCU → BOM → BLR
# 487                       DEL → HYD → COK
# 488                       DEL → BOM → COK
# 489                       CCU → DEL → BLR
# 490                       DEL → MAA → COK
# 491                 CCU → BOM → HBX → BLR
# 492                       DEL → BOM → COK
# 493                       DEL → BOM → COK
# 494                             MAA → CCU
# 495                             MAA → CCU
# 496                 DEL → AMD → BOM → COK
# 497                 DEL → JAI → BOM → COK
# 498                             BLR → DEL
# 499                       CCU → BOM → BLR
# 500                       DEL → HYD → COK
# 501                 DEL → IDR → BOM → COK
# 502                       DEL → BOM → COK
# 503                 DEL → GOI → BOM → COK
# 504                             MAA → CCU
# 505                       CCU → BOM → BLR
# 506                       DEL → BOM → COK
# 507                       BLR → BOM → DEL
# 508                             CCU → BLR
# 509                       BLR → BOM → DEL
# 510                 DEL → AMD → BOM → COK
# 511                       DEL → MAA → COK
# 512                             BLR → DEL
# 513                             BOM → HYD
# 514                       DEL → BOM → COK
# 515                 DEL → HYD → MAA → COK
# 516                 DEL → HYD → MAA → COK
# 517                       DEL → MAA → COK
# 518                             CCU → BLR
# 519                             CCU → BLR
# 520                             DEL → COK
# 521                       DEL → BOM → COK
# 522                             BLR → DEL
# 523                       DEL → BOM → COK
# 524                 DEL → JAI → BOM → COK
# 525                       CCU → BOM → BLR
# 526                             BOM → HYD
# 527                 DEL → JAI → BOM → COK
# 528                             BLR → DEL
# 529                             BOM → HYD
# 530                       DEL → HYD → COK
# 531                 DEL → ATQ → BOM → COK
# 532                       DEL → HYD → COK
# 533                 DEL → NAG → BOM → COK
# 534                             BLR → DEL
# 535                       DEL → BOM → COK
# 536                       CCU → BOM → BLR
# 537                       CCU → BOM → BLR
# 538                             BLR → DEL
# 539                             BLR → DEL
# 540                             BLR → DEL
# 541                             MAA → CCU
# 542                       DEL → BLR → COK
# 543                             BOM → HYD
# 544                       DEL → BOM → COK
# 545                       DEL → BOM → COK
# 546                             BLR → DEL
# 547                       DEL → BOM → COK
# 548                       CCU → BOM → BLR
# 549                             CCU → BLR
# 550                             BOM → HYD
# 551                       DEL → BOM → COK
# 552                             DEL → COK
# 553                       CCU → IXB → BLR
# 554                 CCU → GAU → DEL → BLR
# 555                       CCU → BBI → BLR
# 556                             BOM → HYD
# 557                             BOM → HYD
# 558                             BLR → DEL
# 559                             BLR → DEL
# 560                       DEL → BOM → COK
# 561                       DEL → BOM → COK
# 562                       DEL → HYD → COK
# 563                 CCU → BOM → COK → BLR
# 564                             DEL → COK
# 565                 DEL → AMD → BOM → COK
# 566                 DEL → IDR → BOM → COK
# 567                             BLR → DEL
# 568                       DEL → BOM → COK
# 569                             BLR → DEL
# 570                       DEL → BOM → COK
# 571                       DEL → HYD → COK
# 572                       DEL → MAA → COK
# 573                       BLR → MAA → DEL
# 574                       CCU → DEL → BLR
# 575                       BLR → BOM → DEL
# 576                 DEL → BHO → BOM → COK
# 577                       CCU → BOM → BLR
# 578                       CCU → BOM → BLR
# 579                       BLR → BOM → DEL
# 580                             BLR → DEL
# 581                       DEL → BOM → COK
# 582                       CCU → BOM → BLR
# 583                       DEL → BOM → COK
# 584                       DEL → BOM → COK
# 585                       BLR → BOM → DEL
# 586                       DEL → BOM → COK
# 587                             BOM → HYD
# 588                             BLR → DEL
# 589                             BLR → DEL
# 590                             DEL → COK
# 591                       DEL → BOM → COK
# 592                             BOM → HYD
# 593                       DEL → BOM → COK
# 594                 DEL → AMD → BOM → COK
# 595                       DEL → BLR → COK
# 596                       DEL → BOM → COK
# 597                       DEL → BOM → COK
# 598                       CCU → PNQ → BLR
# 599                       DEL → BOM → COK
# 600                       CCU → DEL → BLR
# 601                       DEL → BOM → COK
# 602                       DEL → BOM → COK
# 603                             BLR → DEL
# 604                             MAA → CCU
# 605                       DEL → BOM → COK
# 606                       BLR → BOM → DEL
# 607                       CCU → BOM → BLR
# 608                       DEL → MAA → COK
# 609                 DEL → HYD → MAA → COK
# 610                       CCU → DEL → BLR
# 611                       DEL → HYD → COK
# 612                       DEL → BOM → COK
# 613                       CCU → BOM → BLR
# 614                             BOM → HYD
# 615                       CCU → MAA → BLR
# 616                             BLR → DEL
# 617                             BOM → HYD
# 618                       CCU → DEL → BLR
# 619                       CCU → DEL → BLR
# 620                       DEL → BOM → COK
# 621                       DEL → BOM → COK
# 622                       DEL → BOM → COK
# 623                       DEL → MAA → COK
# 624                       BLR → BOM → DEL
# 625                       DEL → BOM → COK
# 626                       CCU → DEL → BLR
# 627                             BOM → HYD
# 628                       CCU → BOM → BLR
# 629                             BOM → HYD
# 630                             CCU → BLR
# 631                       CCU → HYD → BLR
# 632                       DEL → BOM → COK
# 633                       DEL → BOM → COK
# 634                       CCU → BOM → BLR
# 635                 CCU → DEL → COK → BLR
# 636                             CCU → BLR
# 637                       BLR → BOM → DEL
# 638                       DEL → BOM → COK
# 639                             DEL → COK
# 640                       DEL → BOM → COK
# 641                       DEL → HYD → COK
# 642                       BLR → STV → DEL
# 643                       CCU → MAA → BLR
# 644                       DEL → BOM → COK
# 645                       DEL → HYD → COK
# 646                             MAA → CCU
# 647                       BLR → AMD → DEL
# 648                       DEL → BOM → COK
# 649                             BLR → DEL
# 650                       CCU → DEL → BLR
# 651                       DEL → BOM → COK
# 652                       DEL → BOM → COK
# 653                       CCU → BBI → BLR
# 654                             CCU → BLR
# 655                 CCU → BBI → BOM → BLR
# 656                             BLR → DEL
# 657                       DEL → BOM → COK
# 658                       CCU → KNU → BLR
# 659                       CCU → KNU → BLR
# 660                       CCU → BOM → BLR
# 661                             CCU → BLR
# 662                       BLR → BOM → DEL
# 663                       DEL → MAA → COK
# 664                 DEL → AMD → BOM → COK
# 665                             BLR → DEL
# 666                       DEL → TRV → COK
# 667                             MAA → CCU
# 668                       DEL → BLR → COK
# 669                             BLR → DEL
# 670                 BLR → CCU → GAU → DEL
# 671                             BLR → DEL
# 672                             DEL → COK
# 673           DEL → RPR → NAG → BOM → COK
# 674                       CCU → BOM → BLR
# 675                       CCU → DEL → BLR
# 676                             BLR → DEL
# 677                       BLR → BOM → DEL
# 678                             CCU → BLR
# 679                 DEL → UDR → BOM → COK
# 680                       CCU → DEL → BLR
# 681                       DEL → BOM → COK
# 682                       CCU → BBI → BLR
# 683                 DEL → AMD → BOM → COK
# 684                             BLR → DEL
# 685                       DEL → BOM → COK
# 686                       CCU → BBI → BLR
# 687                       DEL → HYD → COK
# 688                       BLR → BOM → DEL
# 689                       DEL → BOM → COK
# 690                             CCU → BLR
# 691                       DEL → BOM → COK
# 692                             CCU → BLR
# 693                             CCU → BLR
# 694                       DEL → BOM → COK
# 695                       DEL → BOM → COK
# 696                       DEL → MAA → COK
# 697                       CCU → DEL → BLR
# 698                 DEL → GOI → BOM → COK
# 699                             BLR → DEL
# 700                 CCU → BOM → HBX → BLR
# 701                       CCU → HYD → BLR
# 702                       DEL → BOM → COK
# 703                       CCU → BOM → BLR
# 704                       DEL → BOM → COK
# 705                       DEL → BOM → COK
# 706                       CCU → BOM → BLR
# 707                       CCU → HYD → BLR
# 708                             DEL → COK
# 709                       BLR → BOM → DEL
# 710                       DEL → BOM → COK
# 711                             BLR → DEL
# 712                       DEL → BOM → COK
# 713                             BOM → HYD
# 714                 DEL → HYD → MAA → COK
# 715                             CCU → BLR
# 716                 DEL → CCU → BOM → COK
# 717                       BOM → BLR → HYD
# 718                       CCU → BOM → BLR
# 719                 DEL → DED → BOM → COK
# 720                       BLR → BOM → DEL
# 721                       DEL → BOM → COK
# 722                       DEL → BOM → COK
# 723                       DEL → BOM → COK
# 724                 CCU → BOM → AMD → BLR
# 725           DEL → RPR → NAG → BOM → COK
# 726                             BLR → DEL
# 727                       DEL → BOM → COK
# 728                       DEL → MAA → COK
# 729                       DEL → BOM → COK
# 730                             BLR → DEL
# 731                       CCU → DEL → BLR
# 732                             MAA → CCU
# 733                             MAA → CCU
# 734                 DEL → JDH → BOM → COK
# 735                       DEL → BOM → COK
# 736                       DEL → HYD → COK
# 737                       DEL → BOM → COK
# 738                             CCU → BLR
# 739                             MAA → CCU
# 740                       CCU → BOM → BLR
# 741                 DEL → JAI → BOM → COK
# 742                       CCU → BOM → BLR
# 743                       CCU → BOM → BLR
# 744                       DEL → BOM → COK
# 745                       DEL → MAA → COK
# 746                             DEL → COK
# 747                       BLR → BOM → DEL
# 748                 CCU → BOM → COK → BLR
# 749                             CCU → BLR
# 750                 CCU → BBI → BOM → BLR
# 751                       DEL → BOM → COK
# 752                             BLR → DEL
# 753                 DEL → NAG → BOM → COK
# 754                             DEL → COK
# 755                       DEL → BOM → COK
# 756                       CCU → BOM → BLR
# 757                       DEL → BOM → COK
# 758                       DEL → BLR → COK
# 759                             BLR → DEL
# 760                             BLR → DEL
# 761                       DEL → BOM → COK
# 762                             BLR → DEL
# 763                             BLR → DEL
# 764                             MAA → CCU
# 765                 DEL → JAI → BOM → COK
# 766                 DEL → HYD → MAA → COK
# 767                             BLR → DEL
# 768                 DEL → JAI → BOM → COK
# 769                             BOM → HYD
# 770                       DEL → BOM → COK
# 771                       BLR → BOM → DEL
# 772                 DEL → BHO → BOM → COK
# 773                             BLR → DEL
# 774                       CCU → DEL → BLR
# 775                             BLR → DEL
# 776                       DEL → HYD → COK
# 777                             BLR → DEL
# 778                       CCU → BOM → BLR
# 779                             BLR → DEL
# 780                       DEL → BOM → COK
# 781                       DEL → BOM → COK
# 782                       CCU → BOM → BLR
# 783                       DEL → AMD → COK
# 784                 DEL → MAA → BOM → COK
# 785                       DEL → BOM → COK
# 786                 DEL → NAG → BOM → COK
# 787                       CCU → BBI → BLR
# 788                 DEL → JDH → BOM → COK
# 789                       CCU → DEL → BLR
# 790                       DEL → BOM → COK
# 791                             BLR → DEL
# 792                             BLR → DEL
# 793                 DEL → AMD → BOM → COK
# 794                 DEL → JAI → BOM → COK
# 795                             MAA → CCU
# 796                       CCU → DEL → BLR
# 797                             BOM → HYD
# 798                       DEL → BLR → COK
# 799                             BLR → DEL
# 800                       DEL → BOM → COK
# 801                       DEL → BOM → COK
# 802                       CCU → DEL → BLR
# 803                       CCU → BOM → BLR
# ...
# 2410                      DEL → HYD → COK
# 2411                      CCU → HYD → BLR
# 2412                      CCU → DEL → BLR
# 2413                            BOM → HYD
# 2414                      DEL → MAA → COK
# 2415                            CCU → BLR
# 2416                BOM → AMD → ISK → HYD
# 2417                            BLR → DEL
# 2418                      DEL → BOM → COK
# 2419                CCU → IXR → DEL → BLR
# 2420                      CCU → BOM → BLR
# 2421                            CCU → BLR
# 2422    BLR → CCU → BBI → HYD → VGA → DEL
# 2423                      CCU → HYD → BLR
# 2424                DEL → CCU → BOM → COK
# 2425                      DEL → HYD → COK
# 2426                      BLR → BOM → DEL
# 2427                            MAA → CCU
# 2428                      DEL → BOM → COK
# 2429                      DEL → BOM → COK
# 2430                      DEL → AMD → COK
# 2431                      CCU → DEL → BLR
# 2432                      DEL → BOM → COK
# 2433                      CCU → BOM → BLR
# 2434                            BLR → DEL
# 2435                      BOM → DEL → HYD
# 2436                            BOM → HYD
# 2437                      CCU → DEL → BLR
# 2438                      BLR → BOM → DEL
# 2439                            BLR → DEL
# 2440                CCU → BOM → COK → BLR
# 2441                            BLR → DEL
# 2442          CCU → BBI → IXR → DEL → BLR
# 2443                            BLR → DEL
# 2444                      BLR → BOM → DEL
# 2445                CCU → IXR → BBI → BLR
# 2446                            BOM → HYD
# 2447                            BLR → DEL
# 2448                DEL → AMD → BOM → COK
# 2449                      DEL → BOM → COK
# 2450                      DEL → BLR → COK
# 2451                      BLR → HYD → DEL
# 2452                            BLR → DEL
# 2453                      BOM → DEL → HYD
# 2454                            CCU → BLR
# 2455                      DEL → BOM → COK
# 2456                            CCU → BLR
# 2457                            BLR → DEL
# 2458                      DEL → HYD → COK
# 2459                            BLR → DEL
# 2460                      CCU → BOM → BLR
# 2461                      DEL → HYD → COK
# 2462                BOM → JAI → DEL → HYD
# 2463                DEL → ATQ → BOM → COK
# 2464                      DEL → BOM → COK
# 2465                      DEL → PNQ → COK
# 2466                DEL → JAI → BOM → COK
# 2467                            BLR → DEL
# 2468                            BLR → DEL
# 2469                      CCU → BOM → BLR
# 2470                      DEL → BOM → COK
# 2471                      DEL → BOM → COK
# 2472                DEL → MAA → BOM → COK
# 2473                      DEL → BOM → COK
# 2474                            CCU → BLR
# 2475                      DEL → BOM → COK
# 2476                      BLR → BOM → DEL
# 2477                            BOM → HYD
# 2478                DEL → IDR → BOM → COK
# 2479                      DEL → PNQ → COK
# 2480                      BLR → BOM → DEL
# 2481                      CCU → HYD → BLR
# 2482                            BLR → DEL
# 2483                            BOM → HYD
# 2484                      DEL → BOM → COK
# 2485                            BLR → DEL
# 2486                DEL → JAI → BOM → COK
# 2487          DEL → GWL → IDR → BOM → COK
# 2488                      DEL → BOM → COK
# 2489                      DEL → BOM → COK
# 2490                      DEL → BOM → COK
# 2491                      DEL → BLR → COK
# 2492                DEL → IDR → BOM → COK
# 2493                      DEL → TRV → COK
# 2494                CCU → IXR → DEL → BLR
# 2495                            CCU → BLR
# 2496                      DEL → BOM → COK
# 2497                            BLR → DEL
# 2498                      DEL → BOM → COK
# 2499                      DEL → BOM → COK
# 2500                            BLR → DEL
# 2501                            BOM → HYD
# 2502                      DEL → PNQ → COK
# 2503                      CCU → BOM → BLR
# 2504                            MAA → CCU
# 2505                            BOM → HYD
# 2506                      BLR → HYD → DEL
# 2507                      DEL → BOM → COK
# 2508                      CCU → DEL → BLR
# 2509                DEL → GOI → BOM → COK
# 2510                      BLR → BOM → DEL
# 2511                CCU → GAU → DEL → BLR
# 2512                            BLR → DEL
# 2513                      DEL → BOM → COK
# 2514                            BLR → DEL
# 2515                      DEL → BOM → COK
# 2516                      DEL → BOM → COK
# 2517                      CCU → HYD → BLR
# 2518                      DEL → MAA → COK
# 2519                      BLR → BOM → DEL
# 2520                            DEL → COK
# 2521                      DEL → BOM → COK
# 2522                            CCU → BLR
# 2523                DEL → JAI → BOM → COK
# 2524                      DEL → BOM → COK
# 2525                      DEL → HYD → COK
# 2526                            BOM → HYD
# 2527                DEL → JAI → BOM → COK
# 2528                            CCU → BLR
# 2529                DEL → HYD → BOM → COK
# 2530                CCU → BBI → BOM → BLR
# 2531                      DEL → MAA → COK
# 2532                            BOM → HYD
# 2533                      DEL → BOM → COK
# 2534                      CCU → BBI → BLR
# 2535                            BLR → DEL
# 2536                DEL → GOI → BOM → COK
# 2537                      DEL → BOM → COK
# 2538                      CCU → BOM → BLR
# 2539                            MAA → CCU
# 2540                      DEL → BOM → COK
# 2541                      DEL → BOM → COK
# 2542                      DEL → HYD → COK
# 2543                            BLR → DEL
# 2544                            MAA → CCU
# 2545                      CCU → BOM → BLR
# 2546                            DEL → COK
# 2547                      DEL → HYD → COK
# 2548                            MAA → CCU
# 2549                      DEL → BOM → COK
# 2550                            BLR → DEL
# 2551                            CCU → BLR
# 2552                            BLR → DEL
# 2553                DEL → JAI → BOM → COK
# 2554                            MAA → CCU
# 2555                            BOM → HYD
# 2556                CCU → BBI → BOM → BLR
# 2557                            BLR → DEL
# 2558                      BLR → BOM → DEL
# 2559                            BOM → HYD
# 2560                      DEL → BOM → COK
# 2561                      CCU → BOM → BLR
# 2562                      DEL → BOM → COK
# 2563                      CCU → GAU → BLR
# 2564                      DEL → BOM → COK
# 2565                            BLR → DEL
# 2566                            BLR → DEL
# 2567                            BOM → HYD
# 2568                DEL → JAI → BOM → COK
# 2569                      BLR → BOM → DEL
# 2570                            BOM → HYD
# 2571                      CCU → DEL → BLR
# 2572                            CCU → BLR
# 2573                      DEL → BOM → COK
# 2574                      DEL → BOM → COK
# 2575                      DEL → BOM → COK
# 2576                            CCU → BLR
# 2577                      DEL → BOM → COK
# 2578                BLR → BOM → AMD → DEL
# 2579                      DEL → MAA → COK
# 2580                            CCU → BLR
# 2581                      BLR → BOM → DEL
# 2582                CCU → BOM → GOI → BLR
# 2583                            BLR → DEL
# 2584                            CCU → BLR
# 2585                DEL → AMD → BOM → COK
# 2586                DEL → BHO → BOM → COK
# 2587                      DEL → BOM → COK
# 2588                            DEL → COK
# 2589                CCU → DEL → COK → BLR
# 2590                            CCU → BLR
# 2591                      DEL → HYD → COK
# 2592                      BLR → MAA → DEL
# 2593                      DEL → BOM → COK
# 2594                      CCU → BOM → BLR
# 2595                            CCU → BLR
# 2596                            BLR → DEL
# 2597                            BLR → DEL
# 2598                      DEL → BOM → COK
# 2599                      DEL → BOM → COK
# 2600                      DEL → MAA → COK
# 2601                            BLR → DEL
# 2602                DEL → JAI → BOM → COK
# 2603                      DEL → BOM → COK
# 2604                      DEL → BOM → COK
# 2605                      DEL → HYD → COK
# 2606                      DEL → BOM → COK
# 2607                      DEL → BOM → COK
# 2608                            BLR → DEL
# 2609                            BOM → HYD
# 2610                            MAA → CCU
# 2611                      DEL → BOM → COK
# 2612                      DEL → BOM → COK
# 2613                            CCU → BLR
# 2614                            BLR → DEL
# 2615                BLR → CCU → GAU → DEL
# 2616                            MAA → CCU
# 2617                            DEL → COK
# 2618                      CCU → DEL → BLR
# 2619                      CCU → DEL → BLR
# 2620                      CCU → BOM → BLR
# 2621                            BLR → DEL
# 2622                            BLR → DEL
# 2623                      DEL → BOM → COK
# 2624                            BLR → DEL
# 2625                            BLR → DEL
# 2626                            BLR → DEL
# 2627                      DEL → BLR → COK
# 2628                      DEL → BOM → COK
# 2629                            CCU → BLR
# 2630                      DEL → BOM → COK
# 2631                      DEL → BOM → COK
# 2632                            BOM → HYD
# 2633                            CCU → BLR
# 2634                      CCU → NAG → BLR
# 2635                      DEL → BOM → COK
# 2636                      BLR → BOM → DEL
# 2637                            BLR → DEL
# 2638                      DEL → HYD → COK
# 2639                CCU → BBI → BOM → BLR
# 2640                            BLR → DEL
# 2641                      DEL → BOM → COK
# 2642                      DEL → BOM → COK
# 2643                DEL → HYD → MAA → COK
# 2644                      DEL → BOM → COK
# 2645                      BLR → BOM → DEL
# 2646                DEL → AMD → BOM → COK
# 2647                CCU → GAU → DEL → BLR
# 2648                            DEL → COK
# 2649                            BLR → DEL
# 2650                CCU → IXR → DEL → BLR
# 2651                      CCU → DEL → BLR
# 2652                      BLR → BOM → DEL
# 2653                      CCU → BOM → BLR
# 2654                      DEL → BOM → COK
# 2655                      DEL → BOM → COK
# 2656                      CCU → BOM → BLR
# 2657                      DEL → BOM → COK
# 2658                      DEL → BOM → COK
# 2659                DEL → BHO → BOM → COK
# 2660                BOM → GOI → PNQ → HYD
# 2661                DEL → AMD → BOM → COK
# 2662                            BOM → HYD
# 2663                      CCU → BOM → BLR
# 2664                      DEL → BOM → COK
# 2665                            BOM → HYD
# 2666                      CCU → DEL → BLR
# 2667                            CCU → BLR
# 2668                      DEL → BOM → COK
# 2669                      DEL → BOM → COK
# 2670                      DEL → BOM → COK
# Name: Route, dtype: object
# --------------------------------------------------
# Drop Route and Additional_Info
# --------------------------------------------------
# Cout Total_Stops
# Total_Stops
# 1 stop      1431
# non-stop     849
# 2 stops      379
# 3 stops       11
# 4 stops        1
# Name: count, dtype: int64
# --------------------------------------------------
# Normalize total stops
# --------------------------------------------------
# Concate flight, airline, source and destionation
# --------------------------------------------------
# Show all rows and columns
# --------------------------------------------------
# Drop Airline, Source and Destination
# --------------------------------------------------
# Show head
#    Total_Stops  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            1            6              6        17          30
# 1            1           12              5         6          20
# 2            1           21              5        19          15
# 3            1           21              5         8           0
# 4            0           24              6        23          55
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             4              25             10               55      False
# 1            10              20              4                0      False
# 2            19               0             23               45      False
# 3            21               0             13                0      False
# 4             2              45              2               50      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False   False         True                 False              False
# 1  False    True        False                 False              False
# 2  False   False         True                 False              False
# 3  False   False        False                 False               True
# 4  False   False        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Vistara  \
# 0                              False     False    False
# 1                              False     False    False
# 2                              False     False    False
# 3                              False     False    False
# 4                              False     False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False          True           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False          True           False
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False                True              False
# 1          False               False              False
# 2          False                True              False
# 3          False                True              False
# 4          False               False               True
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                  False
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                  False
# --------------------------------------------------
# Shape
# (2671, 28)
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\2314376658.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight_test['Dep_hour'] = pd.to_datetime(flight_test.Dep_Time ).dt.hour
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\2314376658.py:34: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight_test['Dep_Minute'] = pd.to_datetime(flight_test.Dep_Time ).dt.minute
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\2314376658.py:43: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight_test['Arrival_hour'] = pd.to_datetime(flight_test.Arrival_Time ).dt.hour
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\2314376658.py:44: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight_test['Arrival_Minute'] = pd.to_datetime(flight_test.Arrival_Time ).dt.minute

# %%
flight_test.head()
# Out:
#    Total_Stops  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            1            6              6        17          30
# 1            1           12              5         6          20
# 2            1           21              5        19          15
# 3            1           21              5         8           0
# 4            0           24              6        23          55
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             4              25             10               55      False
# 1            10              20              4                0      False
# 2            19               0             23               45      False
# 3            21               0             13                0      False
# 4             2              45              2               50      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False   False         True                 False              False
# 1  False    True        False                 False              False
# 2  False   False         True                 False              False
# 3  False   False        False                 False               True
# 4  False   False        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Vistara  \
# 0                              False     False    False
# 1                              False     False    False
# 2                              False     False    False
# 3                              False     False    False
# 4                              False     False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False          True           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False          True           False
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False                True              False
# 1          False               False              False
# 2          False                True              False
# 3          False                True              False
# 4          False               False               True
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                  False
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                  False

# %%
flight.head()
# Out:
#    Total_Stops  Price  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            0   3897           24              3        22          20
# 1            2   7662            1              5         5          50
# 2            2  13882            9              6         9          25
# 3            1   6218           12              5        18           5
# 4            1  13302            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             1              10              2               50      False
# 1            13              15              7               25       True
# 2             4              25             19                0      False
# 3            23              30              5               25      False
# 4            21              35              4               45      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False    True        False                 False              False
# 1  False   False        False                 False              False
# 2  False   False         True                 False              False
# 3  False    True        False                 False              False
# 4  False    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
# 2                              False     False   False    False
# 3                              False     False   False    False
# 4                              False     False   False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True

# %% [markdown]
# ## Feature selection

# %%
flight.shape , flight_test.shape
# Out:
# ((10682, 30), (2671, 28))

# %%
X = flight.drop(columns='Price',axis=1)
y = flight['Price']
X.head()
# Out:
#    Total_Stops  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            0           24              3        22          20
# 1            2            1              5         5          50
# 2            2            9              6         9          25
# 3            1           12              5        18           5
# 4            1            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             1              10              2               50      False
# 1            13              15              7               25       True
# 2             4              25             19                0      False
# 3            23              30              5               25      False
# 4            21              35              4               45      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False    True        False                 False              False
# 1  False   False        False                 False              False
# 2  False   False         True                 False              False
# 3  False    True        False                 False              False
# 4  False    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
# 2                              False     False   False    False
# 3                              False     False   False    False
# 4                              False     False   False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True

# %%
y.head()
# Out:
# 0     3897
# 1     7662
# 2    13882
# 3     6218
# 4    13302
# Name: Price, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(flight.corr() , annot=True , cmap = 'RdYlGn')
plt.show()

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor()
etr.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
plt.figure(figsize=(20,20))

feat = pd.Series(etr.feature_importances_ , index=X.columns)
feat.nlargest(20).plot(kind='barh')

plt.show()

# %% [markdown]
# ## Fit model using Random Forest

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2 , random_state=51)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train , y_train)
# Out:
# RandomForestRegressor()

# %%
pred = rfr.predict(X_test)

# %%
rfr.score(X_train , y_train)
# Out:
# 0.9547134921862273

# %%
rfr.score(X_test , y_test)
# Out:
# 0.8275567937567385

# %%
sns.distplot(y_test - pred)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\2485339681.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test - pred)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
plt.scatter(y_test , pred , alpha=0.8)
plt.xlabel('y_test')
plt.ylabel('pred')
# Out:
# Text(0, 0.5, 'pred')

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 1133.325526110932
# MSE: 3232671.3168179626
# RMSE: 1797.9631021847924

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.8275567937567385

# %% [markdown]
# ## Hyperprameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(100,2000,10)]
max_depth = [int(x) for x in np.linspace(100,2000,10)]
min_samples_split=[2,4,6,8,10,12,14]
min_samples_leaf=[1,3,5,7,8,10]
max_features=['sqrt','log2','auto',None]

random_search = {
    'n_estimators' : n_estimators,
    'max_depth' : max_depth,
    'min_samples_split' : min_samples_split,
    'min_samples_leaf' : min_samples_leaf,
    'max_features' : max_features,
    
}

random_search
# Out:
# {'n_estimators': [100, 311, 522, 733, 944, 1155, 1366, 1577, 1788, 2000],
#  'max_depth': [100, 311, 522, 733, 944, 1155, 1366, 1577, 1788, 2000],
#  'min_samples_split': [2, 4, 6, 8, 10, 12, 14],
#  'min_samples_leaf': [1, 3, 5, 7, 8, 10],
#  'max_features': ['sqrt', 'log2', 'auto', None]}

# %%
rfr_random = RandomizedSearchCV(estimator=rfr , param_distributions=random_search , n_iter=10 , cv=5 , verbose=2 , random_state=51 , n_jobs=1)

# %%
rfr_random.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  14.2s
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  13.9s
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  14.4s
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  14.4s
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  14.7s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  27.5s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  27.3s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  27.5s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  27.8s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  27.7s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.8s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   1.3s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.8s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   1.5s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  13.9s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  14.4s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  14.4s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  14.9s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  14.1s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.4s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.2s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.3s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.2s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.2s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  52.6s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  51.5s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  50.7s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  49.3s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  50.2s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=   9.5s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=   9.5s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=   9.5s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=   9.3s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=   9.2s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  12.5s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  12.3s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  12.7s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  12.7s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  12.5s
# C:\Users\akhil\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 10 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\akhil\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\akhil\anaconda3\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\akhil\anaconda3\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\akhil\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\akhil\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.72235993 0.78763069 0.77048385        nan 0.72170898 0.80589682
#         nan 0.78327287 0.70490799 0.78830873]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [100, 311, 522, 733, 944,
#                                                       1155, 1366, 1577, 1788,
#                                                       2000],
#                                         'max_features': ['sqrt', 'log2', 'auto',
#                                                          None],
#                                         'min_samples_leaf': [1, 3, 5, 7, 8, 10],
#                                         'min_samples_split': [2, 4, 6, 8, 10,
#                                                               12, 14],
#                                         'n_estimators': [100, 311, 522, 733,
#                                                          944, 1155, 1366, 1577,
#                                                          1788, 2000]},
#                    random_state=51, verbose=2)

# %%
rfr_random.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 10,
#  'min_samples_leaf': 3,
#  'max_features': None,
#  'max_depth': 522}

# %%
prediction = rfr_random.predict(X_test)

# %%
plt.figure(figsize = (8,8))
sns.distplot(y_test-prediction)
plt.show()
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_22328\375150797.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-prediction)

# %%
plt.scatter(y_test , pred , alpha=0.8)
plt.xlabel('y_test')
plt.ylabel('pred')
# Out:
# Text(0, 0.5, 'pred')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 1090.0698139199187
# MSE: 2689387.007351468
# RMSE: 1639.9350619312545

# %%
metrics.r2_score(y_test,prediction)
# Out:
# 0.8565376826391495

# %% [markdown]
# ## Save the model

# %%
import pickle
file = open('Flight-Fare-Prediction.pkl','wb')
pickle.dump(rfr_random,file)

# %%
model = open('Flight-Fare-Prediction.pkl','rb')
mod = pickle.load(model)

# %%
predicted_data = mod.predict(X_test)

# %%
metrics.r2_score(y_test,predicted_data)
# Out:
# 0.8565376826391495
